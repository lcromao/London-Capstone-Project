# %%
import pandas as pd

# %% [markdown]
# ### Análise do dataset de saúde

# %%
health_df = pd.read_excel('data/WellBeing/Tabela Health.xlsx')
health_df.dropna(columns=['Borough'], inplace=True)
health_df = health_df.round(4)

# %%
# Creating a correlation heatmap ploting the following datasets at the same canvas:
# health_df_2016, health_df_2017, health_df_2018, health_df_2019, health_df_2020, health_df_2021, health_df_2022

# Creating a correlation heatmap ploting the following datasets at the same canvas:


def correlation_heatmap(df):
    import seaborn as sns
    import matplotlib.pyplot as plt
    plt.figure(figsize=(15, 15))
    sns.heatmap(df.iloc[:,1:].corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
    plt.show()

for i in health_by_year:
    correlation_heatmap(i)

# %%
health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Borough          231 non-null    object
#  1   Year             231 non-null    int64
#  2   Exercices        231 non-null    float64
#  3   Wellbeing        231 non-null    float64
#  4   Mental           231 non-null    float64
#  5   Obesity          231 non-null    float64
#  6   Cronic Deseases  231 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 12.8+ KB

# %%
financial_df_general = financial_df.groupby('Year').mean()
financial_df_general
# Out:
#             Rough sleepers (%)  Up-to-date with household bills   \
# Year
# 2016-01-01            0.001384                          0.934064
# 2017-01-01            0.001279                          0.926564
# 2018-01-01            0.001479                          0.922188
# 2019-01-01            0.001797                          0.916564
# 2020-01-01            0.001852                          0.921876
# 2021-01-01            0.001415                          0.919688
# 2022-01-01            0.001661                          0.919688
#
#             Unemployment rate   Reducing local income inequality (%)  \
# Year
# 2016-01-01            0.054312                              0.046085
# 2017-01-01            0.050282                              0.050179
# 2018-01-01            0.046094                              0.057406
# 2019-01-01            0.048970                              0.059976
# 2020-01-01            0.064406                              0.056952
# 2021-01-01            0.044030                              0.060879
# 2022-01-01            0.046800                              0.059270
#
#             WellBeing
# Year
# 2016-01-01   0.793612
# 2017-01-01   0.795630
# 2018-01-01   0.809488
# 2019-01-01   0.804200
# 2020-01-01   0.752306
# 2021-01-01   0.784382
# 2022-01-01   0.789885

# %%
correlation_heatmap(financial_df_general)
